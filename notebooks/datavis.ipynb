# %%
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
# %cd /tmp/pycharm_project_813
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /tmp/pycharm_project_813
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dhdrnet.Dataset import HDRDataset
from dhdrnet.vis_util import view_data_sample
DATA_DIR = Path("/mnt/zfspool/data/HDR+")
dataset = HDRDataset(
    DATA_DIR / "train" / "merged",
    DATA_DIR / "train" / "dngs",
)
view_data_sample(dataset)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# %pwd
# Out:
# '/tmp/pycharm_project_813'
